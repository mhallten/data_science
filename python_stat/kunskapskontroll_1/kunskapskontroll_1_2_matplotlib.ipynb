# %% [markdown]
# # Matplotlib
# Read the tutorials: "Basic Usage" and "Pyplot Tutorial" in the link: https://matplotlib.org/stable/tutorials/index.html before solving the exercises below. The "Pyplot Tutorial" you do not read in detail but it is good to know about since the fact that there are two approaches to plotting can be confusing if you are not aware of both of the approaches.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting in Matplotlib can be done in either of two ways, which ones? Which way is the recommended approach?

# %%
""" 
You can plot in Matplotlib by either the object oriented (OO) or the pyplot style. 
In general the OO style is recommended. The OO style have more flexibility it can be used to customize the plots more.
The pyplot method can be used to quickly make ana analysis

"""

# %% [markdown]
# ### Explain shortly what a figure, axes, axis and an artist is in Matplotlib.

# %%
""" 
Figure = The whole figure. The figure keeps track of all the child axes. A figure can contain one ore more axes.
Axes = An Axes is a region where you can plot your data.
Axis = These objects set the scale and limits and generate ticks and ticklabels. They are referred to the X- and Y-axis
Artist = An Artist is a low-level object that represents individual graphic elements in the plot, for exeample a line or dot. 
"""

# %% [markdown]
# ### When plotting in Matplotlib, what is the expected input data type?

# %%
""" 
Everything that is arraylike:
- numpy.arrays
- dataframe
- list
"""
# Out:
# ' \nEverything that is arraylike:numpy.arrays '

# %% [markdown]
# ### Create a plot of the function y = x^2 [from -4 to 4, hint use the np.linspace function] both in the object-oriented approach and the pyplot approach. Your plot should have a title and axis-labels.

# %%
""" The OO style """
x = np.linspace(-4, 4, 100)

y = x**2

fig, ax = plt.subplots()
ax.plot(x, y, label='y = x^2', color='blue')
ax.set_title('Plot of y = x^2')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend()
plt.grid(False)

""" Show OO style plot """

plt.show()

""" The pyplot style """
plt.plot(x, y, label='y = x^2', color='red')
plt.title('Plot of y = x^2')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)

""" Show OO style plot """

plt.show()

# %% [markdown]
# ### Create a figure containing 2  subplots where the first is a scatter plot and the second is a bar plot. You have the data below.

# %%
# Data for scatter plot
np.random.seed(15)
random_data_x = np.random.randn(1000)
random_data_y = np.random.randn(1000)
x = np.linspace(-2, 2, 100)
y = x**2

# Data for bar plot
fruit_data = {'grapes': 22, 'apple': 8, 'orange': 15, 'lemon': 20, 'lime': 25}
names = list(fruit_data.keys())
values = list(fruit_data.values())

# ax1.plot(x, y, 'r', label= 'x^2')

# %%
""" Create figure """
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (12, 5))

""" Scatterplot """
ax1.scatter(random_data_x, random_data_y, marker='o', s=10, c='b', label='Random Data')
ax1.set_title('Scatter Plot')
ax1.set_xlabel('X-axis')
ax1.set_ylabel('Y-axis')
ax1.legend()

""" Barplot """
ax2.bar(names, values, color='g')
ax2.set_title('Fruit Data Bar Plot')
ax2.set_xlabel('Fruit')
ax2.set_ylabel('Count')

""" Show plot """
plt.tight_layout()
plt.show()
